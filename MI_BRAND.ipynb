# %% [markdown]
# <a href="https://colab.research.google.com/github/MansiSurti11/AI-Tool-Spend-Analysis-and-Categorization/blob/main/MI_BRAND.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import modules
import pandas as pd # for dataframes
import matplotlib.pyplot as plt # for plotting graphs
import seaborn as sns # for plotting graphs
import numpy as np

# %% [markdown]
# # New Section

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ae3c3084-113a-47bf-8719-9eea0f662c87" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae3c3084-113a-47bf-8719-9eea0f662c87">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#stores the data
df = pd.read_csv('MI_BRAND.csv')

#print the first 7 row the data
df.head()
# Out:
#    SR. NO  EMPLOYEE NO. EMPLOYEE NAME          CLIENT WORK   JOIN DATE  DAYS  \
# 0       1       2101001    Astha Puri                HONDA  21-02-2021   731
# 1       2       2101002    sneha soni                ADANI  25-02-2019  1458
# 2       3       2101003    riya gupta  PROPER PLACEMENT HR  26-07-2019  1307
# 3       4       2101004   aliya patel               GOZZBY  01-01-2016  2609
# 4       5       2101005   Bijal Pande                 AMUL  27-05-2016  2462
#
#    TENURE  YEAR_OF_EXPERIENCE  ABSENT  PRESENT  ... EVALUATION_LEVEL  \
# 0    2.00                   2      80      443  ...             1.65
# 1    3.99                   4     281      762  ...             1.43
# 2    3.58                   4      53      881  ...             1.84
# 3    7.15                   7      13     1851  ...             1.09
# 4    6.75                   7      34     1725  ...             1.88
#
#                 DESIGNATION          SALARY  PROJECT  TIME_SPEND_COMPANY  \
# ...

# %%
#check attributes names and datatypes using info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SR. NO              5000 non-null   int64
#  1   EMPLOYEE NO.        5000 non-null   int64
#  2   EMPLOYEE NAME       5000 non-null   object
#  3   CLIENT WORK         5000 non-null   object
#  4   JOIN DATE           5000 non-null   object
#  5   DAYS                5000 non-null   int64
#  6   TENURE              5000 non-null   float64
#  7   YEAR_OF_EXPERIENCE  5000 non-null   int64
#  8   ABSENT              5000 non-null   int64
#  9   PRESENT             5000 non-null   int64
#  10  PRESENT P.          5000 non-null   object
#  11  ABSENT P.           5000 non-null   object
#  12  ATTRITION           5000 non-null   object
#  13  WORKING DAYS        5000 non-null   int64
#  14  WEEKEND DAYS        5000 non-null   int64
# ...

# %%
#you have two types of employee one who stayed and another who left the company.
#So, you can divide data into two groups and compare their characteristics.
#Here, you can find the average of both the groups using groupby() and mean() function.
left=df.groupby('NL/L')
left.mean()
# Out:
# <ipython-input-5-3572719d6274>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   left.mean()
#            SR. NO  EMPLOYEE NO.         DAYS    TENURE  YEAR_OF_EXPERIENCE  \
# NL/L
# 0     2480.429967  2.103480e+06  1943.562541  5.320879            5.362541
# 1     2532.424870  2.102551e+06  1998.605181  5.471554            5.532642
#
#           ABSENT      PRESENT  WORKING DAYS  WEEKEND DAYS  SATISFACTION_LEVEL  \
# NL/L
# 0     208.138762  1180.943648   1389.041694    554.520847            8.190228
# 1     314.102591  1114.273057   1428.375648    570.229534            7.616062
#
#       EVALUATION_LEVEL   PROJECT  TIME_SPEND_COMPANY  PROBABILITY      COUNT  \
# NL/L
# 0             1.625482  2.996743            4.810423     0.284685  51.913580
# ...

# %%
num_projects=df.groupby('PROJECT').count()
plt.bar(num_projects.index.values, num_projects['SATISFACTION_LEVEL'])
plt.xlabel('Number of Projects')
plt.ylabel('Number of Employees')
plt.show()

# %%
time_spent=df.groupby('TIME_SPEND_COMPANY').count()
plt.bar(time_spent.index.values, time_spent['SATISFACTION_LEVEL'])
plt.xlabel('Number of hours in a day  Spend in Company')
plt.ylabel('Number of Employees')
plt.show()

# %%
#get the number of rows and cols
df.shape
# Out:
# (5000, 26)

# %%
#get the column data types
df.dtypes
# Out:
# SR. NO                  int64
# EMPLOYEE NO.            int64
# EMPLOYEE NAME          object
# CLIENT WORK            object
# JOIN DATE              object
# DAYS                    int64
# TENURE                float64
# YEAR_OF_EXPERIENCE      int64
# ABSENT                  int64
# PRESENT                 int64
# PRESENT P.             object
# ABSENT P.              object
# ATTRITION              object
# WORKING DAYS            int64
# WEEKEND DAYS            int64
# SATISFACTION_LEVEL      int64
# EVALUATION_LEVEL      float64
# DESIGNATION            object
# SALARY                 object
# PROJECT                 int64
# TIME_SPEND_COMPANY      int64
# PROBABILITY           float64
# NL/L                    int64
# WORK                   object
# COUNT                 float64
# NL                    float64
# dtype: object

# %%
#get a count the empty value for each column
df.isna().sum()
# Out:
# SR. NO                   0
# EMPLOYEE NO.             0
# EMPLOYEE NAME            0
# CLIENT WORK              0
# JOIN DATE                0
# DAYS                     0
# TENURE                   0
# YEAR_OF_EXPERIENCE       0
# ABSENT                   0
# PRESENT                  0
# PRESENT P.               0
# ABSENT P.                0
# ATTRITION                0
# WORKING DAYS             0
# WEEKEND DAYS             0
# SATISFACTION_LEVEL       0
# EVALUATION_LEVEL         0
# DESIGNATION              0
# SALARY                   0
# PROJECT                  0
# TIME_SPEND_COMPANY       0
# PROBABILITY              0
# NL/L                     0
# WORK                  4866
# COUNT                 4866
# NL                    4866
# dtype: int64

# %%
#print all of the data types and their unique values
for column in df.columns:
  if df[column].dtype == object:
    print(str(column) + ':'+ str(df[column].unique()))
    print(df[column].value_counts())
    print('___________________________________________')
# Out:
# EMPLOYEE NAME:['Astha Puri' 'sneha soni' 'riya gupta' 'aliya patel' 'Bijal Pande'
#  'Chirag Sharma' 'Divya Soni' 'Erum Rastogi' 'Farhan Patel' 'Geet Sahu'
#  'Himesh Surya' 'Imran Abha' 'Jitendra Pande' 'Kailash Rane' 'Luv Patel'
#  'Manoj Bhide' 'Nancy Pastor' 'Omar Shaikh' 'Preetam Chavla' 'Ram Vihaan'
#  'Umesh Bajrang' 'rhna sharma' 'siya patel' 'ram patodiya' 'komal p.'
#  'rahna sharma' 'Raj Sharma' 'Sharad Gandhi' "Danish D'Souza"
#  'Pawan Patil' 'Rijo Paul' 'Joseph P' 'Aakash Patel' 'Ganesh Rahu'
#  'Vinudas K.S' 'Divya Kumar' 'Shilpa R' 'Sindhu J.P' 'Deepthi P.S'
#  'Lijin k c' 'Sayad K M' 'Ajil k Mohanan' 'Edison ML' 'Basil P E'
#  'Jobin George' 'Jismon Tomy' 'Sharafali P' 'A KEERTHANA' 'ADITYA PATEL'
#  'ADITYA PASARI' 'AHIR NIDHIKUMARI MAGANBHAI'
#  'CHRISTIAN ANDREW KETANKUMAR' 'SHAH ANSHUMI PRADIPBHAI'
#  'BHIMANI ARPIT NIPULBHAI' 'VISHWAKARMA ARYAN ANILKUMAR'
#  'ASHWINI RAMSING PATIL' 'ASNANI SARANG NARESH'
#  'BHANDERI BANSI JAGDISHBHAI' 'BHATT DHYEY NILESHBHAI'
# ...

# %%
#view some statistics
df.describe()
# Out:
#             SR. NO  EMPLOYEE NO.         DAYS       TENURE  \
# count  5000.000000  5.000000e+03  5000.000000  5000.000000
# mean   2500.500000  2.103122e+06  1964.809000     5.379040
# std    1443.520003  2.681069e+04   615.351637     1.684507
# min       1.000000  2.104480e+05   235.000000     0.640000
# 25%    1250.750000  2.102250e+06  1475.000000     4.040000
# 50%    2500.500000  2.103500e+06  2158.000000     5.910000
# 75%    3750.250000  2.104750e+06  2477.000000     6.780000
# max    5000.000000  2.106000e+06  2609.000000     7.150000
#
#        YEAR_OF_EXPERIENCE       ABSENT      PRESENT  WORKING DAYS  \
# count         5000.000000  5000.000000  5000.000000    5000.00000
# mean             5.428200   249.040800  1155.208800    1404.22460
# std              1.765635   142.772647   446.881441     439.53917
# min              1.000000    11.000000     8.000000     168.00000
# 25%              4.000000   123.000000   835.000000    1054.00000
# ...

# %%
#visualize the correlation
plt.figure(figsize=(14,14))
sns.heatmap(df.corr(),annot=True, fmt= '.0%')
# Out:
# <ipython-input-13-c42efd7173ca>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True, fmt= '.0%')
# <Axes: >

# %%
df['ATTRITION'].value_counts()
# Out:
# NO     3516
# YES    1484
# Name: ATTRITION, dtype: int64

# %%
df['CLIENT WORK'].value_counts()
# Out:
# Paper                             621
# Binders and Binder Accessories    494
# Telephones and Communication      462
# Office Furnishings                435
# Computer Peripherals              393
#                                  ...
# SUNFLOWER                           1
# WAPCOS LIMITED                      1
# VICCO GROUP                         1
# APTECH                              1
# ATUL                                1
# Name: CLIENT WORK, Length: 135, dtype: int64

# %%
import matplotlib.pyplot as plt
f = plt.figure()
f.set_figwidth(300)
f.set_figheight(5)
sns.countplot(df['CLIENT WORK'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-5b6e1b685cc5> in <cell line: 5>()
#       3 f.set_figwidth(300)
#       4 f.set_figheight(5)
# ----> 5 sns.countplot(df['CLIENT WORK'])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2941         raise ValueError("Cannot pass values for both `x` and `y`")
#    2942
# -> 2943     plotter = _CountPlotter(
#    2944         x, y, hue, data, order, hue_order,
#    2945         estimator, errorbar, n_boot, units, seed,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
# ...

# %%
left_count=df.groupby('NL/L').count()
plt.bar(left_count.index.values, left_count['SATISFACTION_LEVEL'])
plt.xlabel('Employees Left Company')
plt.ylabel('Number of Employees')
plt.show()

# %%
sns.countplot(df['ATTRITION'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-9291100d4768> in <cell line: 1>()
# ----> 1 sns.countplot(df['ATTRITION'])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2941         raise ValueError("Cannot pass values for both `x` and `y`")
#    2942
# -> 2943     plotter = _CountPlotter(
#    2944         x, y, hue, data, order, hue_order,
#    2945         estimator, errorbar, n_boot, units, seed,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1528                  errcolor, errwidth, capsize, dodge):
# ...

# %%
#This is the percentage if we just gussed no for attrition
(3516 - 1484)/3516
# Out:
# 0.5779294653014789

# %%
#show the number of employees that left and stayed by tenure
import matplotlib.pyplot as plt
plt.subplots(figsize=(300,5))
sns.countplot(x='CLIENT WORK',hue='ATTRITION', data= df, palette= 'colorblind')
# Out:
# <Axes: xlabel='CLIENT WORK', ylabel='count'>

# %%
#show the number of employees that left and stayed by tenure
import matplotlib.pyplot as plt
plt.subplots(figsize=(300,5))
plt.rcParams['figure.figsize'] = [4, 4]
sns.countplot(x='TENURE',hue='ATTRITION', data= df, palette= 'colorblind')
# Out:
# <Axes: xlabel='TENURE', ylabel='count'>

# %%
#print the perticular employee details
import csv

filePath = "MI_BRAND.csv"

with open(filePath) as csvfile:
    reader = csv.DictReader(csvfile)
    EMPLOYEE_NO = input('Enter the employee number: ')
    for row in reader:
        if EMPLOYEE_NO == row['EMPLOYEE NO.']:
            for k,v in row.items():
                print(k,':',v)
            break
    else:
        print('This number does not exist')
# Out:
# Enter the employee number: 2101005
# SR. NO : 5
# EMPLOYEE NO. : 2101005
# EMPLOYEE NAME : Bijal Pande
# CLIENT WORK : AMUL
# JOIN DATE : 27-05-2016
# DAYS : 2462
# TENURE : 6.75
# YEAR_OF_EXPERIENCE : 7
# ABSENT : 34
# PRESENT : 1725
# PRESENT P. : 98%
# ABSENT P. : 2%
# ATTRITION : NO
# WORKING DAYS : 1759
# WEEKEND DAYS : 703
# SATISFACTION_LEVEL : 9
# EVALUATION_LEVEL : 1.88
# DESIGNATION : human resources director
# SALARY : ? 6,00,000.00
# PROJECT : 4
# TIME_SPEND_COMPANY : 6
# PROBABILITY : 0.073
# NL/L : 0
# WORK : AMUL
# COUNT : 21
# NL : 13

# %%
#Subplot using seaborn
features=['PROJECT','NL/L', 'TIME_SPEND_COMPANY','DESIGNATION','SALARY']
fig=plt.subplots(figsize=(10,15))
for i, j in enumerate(features):
    plt.subplot(4, 2, i+1)
    plt.subplots_adjust(hspace = 1.0)
    sns.countplot(x=j,data = df)
    plt.xticks(rotation=90)
    plt.title("No. of employee")
# Out:
# <ipython-input-22-1e05ef5caeb1>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(4, 2, i+1)

# %%
fig=plt.subplots(figsize=(10,15))
for i, j in enumerate(features):
    plt.subplot(4, 2, i+1)
    plt.subplots_adjust(hspace = 1.0)
    sns.countplot(x=j,data = df, hue='NL/L')
    plt.xticks(rotation=90)
    plt.title("No. of employee")
# Out:
# <ipython-input-23-226ef0cd04da>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(4, 2, i+1)

# %%
#Cluster Analysis
#import module
from sklearn.cluster import KMeans
# Filter data
left_emp =  df[['SATISFACTION_LEVEL','EVALUATION_LEVEL']][df.NL == 1]
# Create groups using K-means clustering.
kmeans = KMeans(n_clusters = 3, random_state = 0).fit(left_emp)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Add new column "label" annd assign cluster labels.
left_emp['label'] = kmeans.labels_
# Draw scatter plot
plt.scatter(left_emp['SATISFACTION_LEVEL'], left_emp['EVALUATION_LEVEL'], c=left_emp['label'],cmap='Accent')
plt.xlabel('Satisfaction Level')
plt.ylabel('Last Evaluation')
plt.title('3 Clusters of employees who left')
plt.show()

# %%
#Building a prediction model
# Import LabelEncoder
from sklearn import preprocessing
#creating labelEncoder
le = preprocessing.LabelEncoder()
# Converting string labels into numbers.
df['SALARY']=le.fit_transform(df['SALARY'])
df['DESIGNATION']=le.fit_transform(df['DESIGNATION'])

# %%
#Split train and test set
#Spliting data into Feature and
X=df[['SATISFACTION_LEVEL','EVALUATION_LEVEL', 'PROJECT',
        'TIME_SPEND_COMPANY',
        'DESIGNATION', 'SALARY']]
y=df['NL/L']

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)  # 70% training and 30% test

# %%
X_train
# Out:
#       SATISFACTION_LEVEL  EVALUATION_LEVEL  PROJECT  TIME_SPEND_COMPANY  \
# 1681                   9              1.84        1                   6
# 674                    8              1.61        5                   5
# 4223                   8              1.59        1                   4
# 2177                   7              1.44        5                   4
# 2915                   8              1.62        4                   5
# ...                  ...               ...      ...                 ...
# 2073                   8              1.55        4                   4
# 4114                   7              1.36        5                   3
# 1642                   9              1.82        1                   6
# 3710                   7              1.40        1                   4
# 2214                   8              1.56        3                   4
#
#       DESIGNATION  SALARY
# 1681            4       4
# 674             1      12
# ...

# %%
X_test
# Out:
#       SATISFACTION_LEVEL  EVALUATION_LEVEL  PROJECT  TIME_SPEND_COMPANY  \
# 3157                   9              1.84        2                   6
# 3786                   9              1.75        1                   5
# 1302                   7              1.36        3                   3
# 4059                   8              1.65        3                   5
# 1582                   9              1.88        2                   6
# ...                  ...               ...      ...                 ...
# 3676                   8              1.57        1                   4
# 1483                   7              1.43        3                   4
# 4068                   8              1.59        3                   4
# 3528                   7              1.45        2                   4
# 3160                   9              1.84        4                   6
#
#       DESIGNATION  SALARY
# 3157           18      18
# 3786           12      16
# ...

# %%
y.size
# Out:
# 5000

# %%
y_test.size
# Out:
# 1500

# %%
y_train.size
# Out:
# 3500

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
Prediction_dt=dt.predict(X_test)
Prediction_dt.size
y_test
# Out:
# 3157    0
# 3786    0
# 1302    1
# 4059    0
# 1582    0
#        ..
# 3676    0
# 1483    1
# 4068    1
# 3528    1
# 3160    0
# Name: NL/L, Length: 1500, dtype: int64

# %%
Prediction_dt
# Out:
# array([0, 0, 1, ..., 0, 1, 0])

# %%
X_test
# Out:
#       SATISFACTION_LEVEL  EVALUATION_LEVEL  PROJECT  TIME_SPEND_COMPANY  \
# 3157                   9              1.84        2                   6
# 3786                   9              1.75        1                   5
# 1302                   7              1.36        3                   3
# 4059                   8              1.65        3                   5
# 1582                   9              1.88        2                   6
# ...                  ...               ...      ...                 ...
# 3676                   8              1.57        1                   4
# 1483                   7              1.43        3                   4
# 4068                   8              1.59        3                   4
# 3528                   7              1.45        2                   4
# 3160                   9              1.84        4                   6
#
#       DESIGNATION  SALARY
# 3157           18      18
# 3786           12      16
# ...

# %%
category=['employee will stay','employee will leave']

# %%
custom_dt=[[0.38,0.50,2,4,13,12]]
print(int(dt.predict(custom_dt)))
# Out:
# 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
category[int(dt.predict(custom_dt))]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 'employee will leave'

# %%
dt.feature_importances_
# Out:
# array([0.01723746, 0.42158314, 0.21088216, 0.01584897, 0.16658654,
#        0.16786172])

# %%
feature_importance=pd.DataFrame(dt.feature_importances_,index=X_train.columns,columns=['Importance']).sort_values('Importance',ascending=False)

# %%
feature_importance
# Out:
#                     Importance
# EVALUATION_LEVEL      0.421583
# PROJECT               0.210882
# SALARY                0.167862
# DESIGNATION           0.166587
# SATISFACTION_LEVEL    0.017237
# TIME_SPEND_COMPANY    0.015849

# %%
#Model Building
#Import Gradient Boosting Classifier model
from sklearn.ensemble import GradientBoostingClassifier

#Create Gradient Boosting Classifier
gb = GradientBoostingClassifier()

#Train the model using the training sets
gb.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = gb.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Model Precision
print("Precision:",metrics.precision_score(y_test, y_pred))
# Model Recall
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.6506666666666666
# Precision: 0.5374280230326296
# Recall: 0.49733570159857904

# %%
df['DESIGNATION'].unique()
# Out:
# array([ 0,  4, 14,  9, 25, 13, 22, 16, 20, 18, 19,  2,  7,  8, 12,  6, 15,
#        24,  3, 23,  5,  1, 17, 11, 10, 21])

# %%
df['SALARY'].unique()
# Out:
# array([ 0,  4, 17, 12, 13,  6, 20,  5, 18, 11,  7,  8, 21, 16,  1, 19, 15,
#         3, 14, 10,  2, 23, 22,  9])

# %%
df.loc[df['EMPLOYEE NO.']==2101005]
# Out:
#    SR. NO  EMPLOYEE NO. EMPLOYEE NAME CLIENT WORK   JOIN DATE  DAYS  TENURE  \
# 4       5       2101005   Bijal Pande        AMUL  27-05-2016  2462    6.75
#
#    YEAR_OF_EXPERIENCE  ABSENT  PRESENT  ... EVALUATION_LEVEL DESIGNATION  \
# 4                   7      34     1725  ...             1.88          14
#
#   SALARY  PROJECT  TIME_SPEND_COMPANY  PROBABILITY  NL/L  WORK  COUNT    NL
# 4     17        4                   6        0.073     0  AMUL   21.0  13.0
#
# [1 rows x 26 columns]

# %%
df.groupby('DESIGNATION').mean()
# Out:
# <ipython-input-50-ce07a294b946>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('DESIGNATION').mean()
#                   SR. NO  EMPLOYEE NO.         DAYS    TENURE  \
# DESIGNATION
# 0            2478.153846  2.103478e+06  1790.591716  4.902426
# 1            2509.077381  2.103509e+06  2006.928571  5.494345
# 2            2431.529412  2.103432e+06  1949.841176  5.337941
# 3            2549.913706  2.103550e+06  2022.913706  5.538020
# 4            2466.398964  2.103466e+06  1976.569948  5.411347
# 5            2495.443878  2.103495e+06  1931.974490  5.289235
# 6            2525.189349  2.103525e+06  1955.727811  5.353728
# 7            2490.534314  2.103491e+06  1934.014706  5.294755
# 8            2465.104046  2.103465e+06  1949.150289  5.336069
# ...

# %%
df['DESIGNATION'].value_counts()
# Out:
# 12    395
# 7     204
# 24    203
# 16    202
# 25    198
# 21    197
# 3     197
# 5     196
# 4     193
# 22    191
# 23    190
# 19    186
# 18    184
# 10    183
# 11    182
# 20    181
# 13    179
# 17    177
# 14    174
# 8     173
# 15    170
# 2     170
# 6     169
# 9     169
# 0     169
# 1     168
# Name: DESIGNATION, dtype: int64

# %%
df['NL/L'].value_counts()
# Out:
# 0    3070
# 1    1930
# Name: NL/L, dtype: int64

# %%
plt.bar(x=df['NL/L'],height=df['COUNT'])
# Out:
# <BarContainer object of 5000 artists>

# %%
plt.bar(x=df['COUNT'],height=df['NL'])
# Out:
# <BarContainer object of 5000 artists>

# %%
sns.barplot(x='NL/L',y='SATISFACTION_LEVEL',data=df)
# Out:
# <Axes: xlabel='NL/L', ylabel='SATISFACTION_LEVEL'>

# %%
sns.pairplot(df,hue='NL/L')

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm

from google.colab import files
uploaded = files.upload()

# Load data from CSV file
data = pd.read_csv('MI_BRAND.csv')

# Define variables
mu = data['ABSENT'].mean()
sigma = data['ABSENT'].std()

# Calculate probability for each employee
for i in range(len(data)):
    tenure = data.iloc[i]['TENURE']
    absenteeism = data.iloc[i]['ABSENT']
    z_score = (absenteeism - mu) / sigma
    prob = norm.cdf(z_score)
    print("Employee", i+1, "probability of being leaving the employee:", prob)
# Out:
#      <input type="file" id="files-d913747d-c12b-4a9c-97c0-853e30e273ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d913747d-c12b-4a9c-97c0-853e30e273ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
